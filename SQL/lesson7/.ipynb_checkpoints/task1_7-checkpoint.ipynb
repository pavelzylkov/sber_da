# %%
import sqlite3
conn = sqlite3.connect('task1_7.db')  
c = conn.cursor()

# %%
import sys
# !{sys.executable} -m pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\pavel\anaconda3\lib\site-packages (4.14.3)
# Requirement already satisfied: six in c:\users\pavel\appdata\roaming\python\python38\site-packages (from plotly) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\pavel\anaconda3\lib\site-packages (from plotly) (1.3.3)

# %%
import plotly.express as px

# %%
import pandas as pd
request = 'select * from test'
df = pd.read_sql_query(request, conn)

# %%
df.head()
# Out:
#    col1  col2  col3
# 0   323   916   768
# 1   444   859   601
# 2   472   755   588
# 3   447    19   408
# 4   751   307   555

# %%
fig = px.histogram(df, nbins=1000, barmode='stack')
fig.show()
# Out:
# <div>                            <div id="a73a99f3-082c-441c-bca9-313baed6d1b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a73a99f3-082c-441c-bca9-313baed6d1b7")) {                    Plotly.newPlot(                        "a73a99f3-082c-441c-bca9-313baed6d1b7",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "variable=col1<br>value=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "col1", "marker": {"color": "#636efa"}, "name": "col1", "nbinsx": 1000, "offsetgroup": "col1", "orientation": "v", "showlegend": true, "type": "histogram", "x": [323, 444, 472, 447, 751, 940, 900, 38, 75, 880, 408, 891, 403, 601, 930, 601, 802, 101, 376, 552, 971, 864, 266, 143, 485, 817, 340, 468, 782, 830, 42, 626, 18, 777, 26, 980, 623, 116, 371, 823, 121, 308, 861, 536, 883, 570, 893, 555, 252, 588, 96, 452, 623, 987, 941, 242, 194, 971, 35, 12, 75, 236, 888, 541, 64, 236, 212, 289, 969, 450, 919, 503, 638, 56, 405, 144, 805, 35, 867, 380, 669, 332, 119, 424, 0, 958, 801, 281, 527, 132, 683, 188, 703, 692, 620, 842, 452, 520, 623, 219, 629, 671, 15, 868, 829, 605, 700, 477, 893, 873, 252, 650, 815, 349, 983, 803, 473, 865, 742, 833, 970, 306, 253, 786, 922, 568, 389, 716, 163, 59, 487, 807, 115, 68, 51, 583, 436, 542, 164, 563, 285, 326, 139, 45, 100, 301, 161, 10, 20, 203, 834, 343, 438, 32, 879, 229, 819, 909, 267, 212, 494, 243, 126, 847, 127, 345, 530, 616, 286, 868, 20, 609, 373, 443, 333, 889, 78, 220, 820, 18, 697, 123, 915, 220, 841, 783, 394, 125, 544, 330, 726, 179, 237, 903, 546, 7, 56, 3, 687, 710, 555, 917, 383, 720, 79, 569, 272, 184, 462, 389, 235, 892, 20, 159, 465, 428, 839, 380, 144, 247, 258, 877, 17, 103, 707, 438, 306, 968, 482, 268, 228, 430, 61, 548, 42, 937, 810, 626, 326, 563, 563, 206, 449, 964, 132