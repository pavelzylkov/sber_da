# %%
import requests
import json
from tqdm.auto import tqdm
from collections import defaultdict
import pickle 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Задание вытащить все вакансии СБЕРа с ХХ (у апи есть ограничение в 2000, подумайте как его обойти)
# Вытащите все описания этих вакансий
# Создайте аналогичный vacancy DataFrame только добавьте поле skills
#  
# Постройте график опубликованных вакансий по датам
# Переведите даты в дни недели, и определите день недели, в который больше всего публикуют вакансий
# Найдите те вакансии с использованием python, которые вам интересны
# Определите по полю skills какие навыки больше всего востребованы для этих вакансий, и
# Постройте график наиболее востребованных вакансий

# %%
def getPage(page=0):
    '''Метод для получения страницы со списком вакансий (по умолчанию страница - 0, т.е. первая)'''
    params = {
        'employer_id': '3529',
        'area': 1,
        'page': page,
        'per_page': 100
    }
    
    res = requests.get('https://api.hh.ru/vacancies', params)
    vacancies = res.json()
    res.close()
    return vacancies

# %%
def getVacancy(vac_id='32698117'):
    '''Метод для получения вакансии (по ее идентификатору)'''
    res = requests.get(f'https://api.hh.ru/vacancies/{vac_id}')
    vacancy = res.json()
    res.close()
    return vacancy

# %%
def makeDataFrame(page=0):
    '''Метод создает pandas.DataFrame по данным из hh.ru.'''
    for page in range(0, getPage(page)['pages'] + 1):
        if page == 0:
            vacancies_df = pd.DataFrame(getPage(page)['items'])
        else:
            vacancies_df = vacancies_df.append(pd.DataFrame(getPage(page)['items']), ignore_index=True)
    return vacancies_df

# %%
def addSkillsColumn(dataframe, page=0):
    '''Добавляет колонку Skills в DataFrame, копируя данные по навыкам из словоря в колонке Snippent по ключу Requirement.'''
    skills_dict = {}
    for page in range(0, getPage(page)['pages'] + 1):
        for df_item in getPage(page)['items']:
            for key, value in df_item['snippet'].items():
                if key == 'requirement':
                    skills_dict[df_item['id']] = value
    return dataframe['id'].map(skills_dict)

# %%
vacancies_df = makeDataFrame() # Сздаем DataFrame
vacancies_df['skills'] = addSkillsColumn(vacancies_df) # Добавляем новую колонку Skills
vacancies_df['published_at'] = pd.to_datetime(vacancies_df['published_at'].str[:10], format='%Y-%m-%d') # Меняем формат поля Дата публикации к виду ГГГГ-ММ-ДД
# vacancies_df['published_at']
vacancies_df.groupby('published_at')['id'].count().sort_values(ascending=False).plot(kind='barh', figsize=(20, 10)); # График по датам публикации

# %%
vacancies_df.head()
# Out:
#          id  premium                                               name  \
# 0  32698117    False                                   Разработчик Java
# 1  33464069    False  Администратор IT систем / SRE (команда SberDev...
# 2  36730688    False                            IOS developer (Sber ID)
# 3  36737287    False                  IOS developer (Зарплатный проект)
# 4  37735943    False                           Аналитик/разработчик DWH
#
#                                           department  has_test  \
# 0  {'id': '3529-3529-prof', 'name': 'Сбер для экс...     False
# 1  {'id': '3529-3529-prof', 'name': 'Сбер для экс...     False
# 2  {'id': '3529-3529-prof', 'name': 'Сбер для экс...     False
# 3  {'id': '3529-3529-prof', 'name': 'Сбер для экс...     False
# 4  {'id': '3529-3529-prof', 'name': 'Сбер для экс...     False
#
#    response_letter_required  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#                                                 area salary  \
# 0  {'id': '1', 'name': 'Москва', 'url': 'https://...   None
# 1  {'id': '1', 'name': 'Москва', 'url': 'https://...   None
# 2  {'id': '1', 'name': 'Москва', 'url': 'https://...   None
# 3  {'id': '1', 'name': 'Москва', 'url': 'https://...   None
# 4  {'id': '1', 'name': 'Москва', 'url': 'https://...   None
#
#                                  type  \
# 0  {'id': 'open', 'name': 'Открытая'}
# 1  {'id': 'open', 'name': 'Открытая'}
# 2  {'id': 'open', 'name': 'Открытая'}
# 3  {'id': 'open', 'name': 'Открытая'}
# 4  {'id': 'open', 'name': 'Открытая'}
#
#                                              address  ... relations  \
# 0  {'city': 'Москва', 'street': 'Варшавское шоссе...  ...        []
# 1  {'city': 'Москва', 'street': 'Кутузовский прос...  ...        []
# 2  {'city': 'Москва', 'street': 'Кутузовский прос...  ...        []
# 3  {'city': 'Москва', 'street': 'Кутузовский прос...  ...        []
# 4                                               None  ...        []
#
#                                             employer  \
# 0  {'id': '3529', 'name': 'Сбербанк', 'url': 'htt...
# 1  {'id': '3529', 'name': 'Сбербанк', 'url': 'htt...
# 2  {'id': '3529', 'name': 'Сбербанк', 'url': 'htt...
# 3  {'id': '3529', 'name': 'Сбербанк', 'url': 'htt...
# 4  {'id': '3529', 'name': 'Сбербанк', 'url': 'htt...
#
#                                              snippet contacts  \
# 0  {'requirement': 'Экспертный уровень core Java ...     None
# 1  {'requirement': 'Уверенные знания Linux. Опыт ...     None
# 2  {'requirement': 'Знание языка Objective-C (зна...     None
# 3  {'requirement': 'Использовать современные подх...     None
# 4  {'requirement': 'Высшее техническое или физико...     None
#
#                                    schedule working_days  \
# 0  {'id': 'fullDay', 'name': 'Полный день'}           []
# 1  {'id': 'fullDay', 'name': 'Полный день'}           []
# 2  {'id': 'fullDay', 'name': 'Полный день'}           []
# 3  {'id': 'fullDay', 'name': 'Полный день'}           []
# 4  {'id': 'fullDay', 'name': 'Полный день'}           []
#
#   working_time_intervals working_time_modes accept_temporary  \
# 0                     []                 []            False
# 1                     []                 []            False
# 2                     []                 []            False
# 3                     []                 []            False
# 4                     []                 []            False
#
#                                               skills
# 0  Экспертный уровень core Java (collections/mult...
# 1  Уверенные знания Linux. Опыт внедрения и сопро...
# 2  Знание языка Objective-C (знание Swift приветс...
# 3  Использовать современные подходы, инструменты ...
# 4  Высшее техническое или физико-математическое о...
#
# [5 rows x 29 columns]

# %%
vacancies_df['published_day_name'] = vacancies_df['published_at'].dt.day_name() # Переводим даты публикации в название дней недели в новую колонку
vacancies_df.groupby('published_day_name')['id'].count().sort_values(ascending=False).nlargest(1) # Больше всего публикуют вакансии в этот день недели
# Out:
# published_day_name
# Monday    369
# Name: id, dtype: int64

# %%
condition_1 = vacancies_df.name.str.contains('analyst|аналитик данных|data|junior', na=False)
condition_2 = vacancies_df.skills.str.contains('python', na=False)
myvacs = vacancies_df[condition_1 | condition_2].reset_index() # Интренсные вакансии с Python

# %%
myvacs['skills']
# Out:
# 0     Знание и опыт работы с ETL, включая развертыва...
# 1     Высшее образование (Математика, Информационные...
# 2     Опыт работы от 1 года в схожих сферах. Знание ...
# 3     Знание архитектуры МРР-СУБД Greenplum, Teradat...
# 4     Высшее техническое образование (Математика, Ин...
# 5     Понимание основ математической статистики. Вла...
# 6     Опыт руководства группой 5-10 сотрудников от 2...
# 7     Опыт разработки на python. Понимание принципов...
# 8     Основное - желание развиваться, стрессоустойчи...
# 9     Образование высшее техническое. Опыт работы св...
# 10    Опыт работы с данными. Уверенное владение Pyth...
# 11    Выбираем оптимальные методы моделирования. Кач...
# 12    Уверенное знание операционных систем Windows и...
# 13    Высшее образование по направлению: прикладная ...
# 14    Образование высшее техническое. Опыт работы св...
# 15    высшее образование по направлению: прикладная ...
# 16    1) Опыт работы в области Data science от одног...
# 17    Опыт работы по направлению работы с данными от...
# 18    Приветствуем отличное знание SQL и понимание к...
# 19    Хорошие знания Python 3. Опыт работа с Pandas,...
# 20    Мы ожидаем, что у вы владеете python на уровне...
# 21    Знание и опыт работы с ETL, включая развертыва...
# 22    Знание SQL. Понимание основ проектирование рел...
# 23    Не менее 2 лет в области Data Mining, реализов...
# 24    Опыт работы разработчиком java/c++, python от ...
# 25    Умение работать в команде. Навыки работы с: Зн...
# 26    Необходимые навыки: Опыт работы с базами данны...
# 27    студент 3+ курса. - знаешь основы кибербезопас...
# 28    Высшее образование - технические специальности...
# 29    Уверенное знание операционных систем Windows и...
# 30    Уверенное знание классических и нейросетевых а...
# 31    Знание основ OC UNIX (RHEL). Навыки программир...
# 32    Выбираем оптимальные методы моделирования. Кач...
# 33    Понимание розничных банковских процессов и про...
# 34    Высшее образование в области экономики/математ...
# 35    Знание математической статистики, методов и ин...
# Name: skills, dtype: object

# %%
vacancies_df.groupby('name')['id'].count().sort_values(ascending=False).nlargest(10).plot(kind='barh', figsize=(20, 10))# Наиболее востребованныу вакансии

# %%
skills_dict = {}
for vac_id in vacancies_df['id']:
    vacancy = getVacancy(vac_id)
    for skill in vacancy['key_skills']:
        if skill.get('name') in skills_dict.keys():
            skills_dict[skill.get('name')] = skills_dict.get(skill.get('name')) + 1
        else:
            skills_dict[skill.get('name')] = 1

# %%
for i in sorted(skills_dict.items(), key=lambda items: items[1], reverse=True):
    print(i)
# Out:
# ('SQL', 150)
# ('Java', 136)
# ('Python', 97)
# ('Git', 79)
# ('Linux', 73)
# ('Atlassian Jira', 72)
# ('PostgreSQL', 60)
# ('Spring Framework', 53)
# ('Agile Project Management', 40)
# ('MS SQL', 37)
# ('Управление проектами', 36)
# ('iOS', 34)
# ('Android', 32)
# ('XML', 31)
# ('JavaScript', 30)
# ('Objective-C', 28)
# ('Английский язык', 26)
# ('Hibernate ORM', 26)
# ('MS PowerPoint', 24)
# ('ООП', 23)
# ('Бизнес-анализ', 23)
# ('Android SDK', 22)
# ('Подготовка презентаций', 21)
# ('Apache Maven', 21)
# ('UML', 20)
# ('BPMN', 18)
# ('REST', 17)
# ('Scrum', 17)
# ('Работа в команде', 17)
# ('Bash', 16)
# ('Базы данных', 16)
# ('Oracle Pl/SQL', 15)
# ('Системный анализ', 15)
# ('Java EE', 15)
# ('C++', 14)
# ('ORACLE', 14)
# ('Java SE', 14)
# ('Аналитическое мышление', 13)
# ('Анализ данных', 12)
# ('Mac Os', 12)
# ('SOAP', 12)
# ('Atlassian Confluence', 12)
# ('Nginx', 11)
# ('MS Access', 11)
# ('JUnit', 11)
# ('Обучение и развитие', 11)
# ('Docker', 10)
# ('Деловое общение', 10)
# ('CSS', 10)
# ('MS Excel', 10)
# ('Jenkins', 9)
# ('База данных: Oracle', 9)
# ('Kotlin', 9)
# ('IOS SDK', 9)
# ('СУБД', 9)
# ('MS Visio', 9)
# ('React', 9)
# ('Cистемы управления базами данных', 8)
# ('UI', 8)
# ('Клиентоориентированность', 8)
# ('HTML', 8)
# ('Разработка технических заданий', 8)
# ('Подбор персонала', 8)
# ('Ориентация на результат', 8)
# ('Swift', 8)
# ('Аналитические исследования', 7)
# ('kotlin', 7)
# ('Тестирование', 7)
# ('UX', 7)
# ('Adobe Dreamweaver', 7)
# ('Управленческая отчетность', 7)
# ('SWIFT Alliance', 6)
# ('Hadoop', 6)
# ('SCALA', 6)
# ('Функциональное тестирование', 6)
# ('Кредитные договоры', 6)
# ('Ведение переговоров', 6)
# ('Проведение презентаций', 6)
# ('ETL', 6)
# ('Деловая коммуникация', 6)
# ('Управление рисками', 6)
# ('Работа с базами данных', 6)
# ('Финансовый анализ', 6)
# ('Разработка нового продукта', 6)
# ('Телефонное интервью', 6)
# ('Django Framework', 5)
# ('Ansible', 5)
# ('Статистический анализ', 5)
# ('Математический анализ', 5)
# ('Математическое моделирование', 5)
# ('Design Patterns', 5)
# ('Kubernetes', 5)
# ('API', 5)
# ('devops', 5)
# ('Less', 5)
# ('Adobe Photoshop', 5)
# ('Оптимизация бизнес-процессов', 5)
# ('Креативность', 5)
# ('Управление отношениями с клиентами', 5)
# ('Грамотная речь', 5)
# ('Информационные технологии', 5)
# ('Администрирование', 5)
# ('Управленческие навыки', 5)
# ('Собеседование', 5)
# ('DWH', 4)
# ('Администрирование серверов Linux', 4)
# ('MVC', 4)
# ('JSON API', 4)
# ('Пользователь ПК', 4)
# ('Openshift', 4)
# ('Zabbix', 4)
# ('Apache Kafka', 4)
# ('MySQL', 4)
# ('Java Servlets', 4)
# ('HTML5', 4)
# ('Redux', 4)
# ('Навыки презентации', 4)
# ('Грамотность', 4)
# ('Opera', 4)
# ('MongoDB', 4)
# ('Умение работать в команде', 4)
# ('Корпоративные финансы', 4)
# ('MS SQL Server', 4)
# ('Node.js', 4)
# ('Мотивация персонала', 4)
# ('Разработка ПО', 3)
# ('SVN', 3)
# ('ITIL', 3)
# ('Холодные продажи', 3)
# ('Активные продажи', 3)
# ('Big Data', 3)
# ('DevOps', 3)
# ('KOTLIN', 3)
# ('C/C++', 3)
# ('Гражданское право', 3)
# ('Банковское право', 3)
# ('.NET Framework', 3)
# ('C#', 3)
# ('Kafka', 3)
# ('IT Recruitment', 3)
# ('Постановка задач разработчикам', 3)
# ('Figma', 3)
# ('MS Project', 3)
# ('Руководство коллективом', 3)
# ('Transact-SQL', 3)
# ('Управление продуктом', 3)
# ('ARIS', 3)
# ('QlikView', 3)
# ('Деловая переписка', 3)
# ('Разработка концепции', 3)
# ('TypeScript', 3)
# ('Прямой поиск', 3)
# ('Тестирование пользовательского интерфейса', 3)
# ('ITSM', 3)
# ('Написание текстов', 3)
# ('CSS3', 3)
# ('Фондовый рынок', 3)
# ('Unix', 3)
# ('CentOS', 3)
# ('Adobe Illustrator', 3)
# ('Проектирование пользовательских интерфейсов', 3)
# ('VMware', 2)
# ('PowerShell', 2)
# ('Управление временем', 2)
# ('беспилотные автомобили', 2)
# ('беспилотник', 2)
# ('self-driving cars', 2)
# ('Планирование', 2)
# ('Data Mining', 2)
# ('Математическая статистика', 2)
# ('NDK', 2)
# ('Нагрузочное тестирование', 2)
# ('JMeter', 2)
# ('Mockito', 2)
# ('ML', 2)
# ('Публичные выступления', 2)
# ('PyTorch', 2)
# ('OpenShift', 2)
# ('ELK', 2)
# ('Маркетинговый анализ', 2)
# ('Прямые продажи', 2)
# ('Системная интеграция', 2)
# ('Zeplin', 2)
# ('Sas', 2)
# ('BitBucket', 2)
# ('Devops', 2)
# ('CI/CD', 2)
# ('Организаторские навыки', 2)
# ('MS Office', 2)
# ('Qlik Sense', 2)
# ('Spring', 2)
# ('react', 2)
# ('Написание статей', 2)
# ('PHP', 2)
# ('Sass', 2)
# ('JSP', 2)
# ('Web-дизайн', 2)
# ('Go', 2)
# ('Golang', 2)
# ('hadoop', 2)
# ('Бюджетирование', 2)
# ('Финансовое планирование', 2)
# ('Системное мышление', 2)
# ('Сбор и анализ информации', 2)
# ('Консультирование', 2)
# ('Копирайтинг', 2)
# ('Стратегия Развития', 2)
# ('Стратегическое планирование', 2)
# ('docker', 2)
# ('Рекрутмент', 2)
# ('Регресионное тестирование', 2)
# ('QA', 2)
# ('XML/Xslt', 2)
# ('Финансовый контроль', 2)
# ('SWIFT', 2)
# ('Техническая поддержка', 2)
# ('Бухгалтерский учет', 2)
# ('Составление договоров', 2)
# ('Active Directory', 2)
# ('Договорная работа', 2)
# ('Маркетинговые коммуникации', 2)
# ('Typescript', 2)
# ('JSON', 2)
# ('VBA', 2)
# ('MQ', 2)
# ('Teradata', 2)
# ('С#', 2)
# ('Анализ рисков', 2)
# ('Tableau', 2)
# ('Работа с большим объемом информации', 2)
# ('методология', 2)
# ('Управление командой', 2)
# ('Развитие продаж', 2)
# ('AngularJS', 2)
# ('Flask', 1)
# ('Поиск и привлечение клиентов', 1)
# ('Автоматизация технологических процессов', 1)
# ('Организация семинаров', 1)
# ('OpenStack', 1)
# ('k8s', 1)
# ('Математическое программирование', 1)
# ('симулятор', 1)
# ('simulator', 1)
# ('planner', 1)
# ('разработка', 1)
# ('C', 1)
# ('JBoss', 1)
# ('IBM WS MQ', 1)
# ('Apache Camel', 1)
# ('HBase', 1)
# ('Solr', 1)
# ('TestNG', 1)
# ('HDFS', 1)
# ('Hive', 1)
# ('Spark', 1)
# ('Impala', 1)
# ('NiFi', 1)
# ('MATLAB', 1)
# ('Разработка продукта', 1)
# ('Adobe', 1)
# ('Mobile Design', 1)
# ('Lead', 1)
# ('JNI', 1)
# ('Intellij IDEA', 1)
# ('TeamCity', 1)
# ('Международное право', 1)
# ('Юридическая поддержка', 1)
# ('Сопровождение сделок', 1)
# ('Проведение внутренних расследований', 1)
# ('Tensorflow', 1)
# ('Numpy', 1)
# ('GridGain', 1)
# ('Jaeger', 1)
# ('Prometheus', 1)
# ('Grafana', 1)
# ('Документальное сопровождение', 1)
# ('it подбор', 1)
# ('рекрутер', 1)
# ('подбор', 1)
# ('Apache Ignite', 1)
# ('ELT', 1)
# ('SketchUp', 1)
# ('Illustrator', 1)
# ('Знание методов проектирования', 1)
# ('аналитика', 1)
# ('Ceph', 1)
# ('Gridgain', 1)
# ('Tomcat', 1)
# ('Koltin', 1)
# ('GitFlow', 1)
# ('RabbitMQ', 1)
# ('Техник', 1)
# ('Сборка конструкций', 1)
# ('FDM', 1)
# ('SLA 3D', 1)
# ('ЕСКД', 1)
# ('СТП', 1)
# ('СДФиР', 1)
# ('CAD', 1)
# ('проработка документации', 1)
# ('сбор требований', 1)
# ('анализ требований', 1)
# ('решение инцидентов', 1)
# ('проведение A/B тестов', 1)
# ('A/B тесты', 1)
# ('Xsd', 1)
# ('описание web-сервисов', 1)
# ('waterfall', 1)
# ('PMBOK', 1)
# ('Офис-менеджер', 1)
# ('Профилактические работы', 1)
# ('Корпоративные мероприятия', 1)
# ('BI', 1)
# ('Сlojure', 1)
# ('Разработка инструкций', 1)
# ('Teamleading', 1)
# ('Администрирование серверов Windows', 1)
# ('TFS', 1)
# ('JS', 1)
# ('jQuery', 1)
# ('TensorFlow', 1)
# ('CV', 1)
# ('Keras', 1)
# ('java core', 1)
# ('Symfony', 1)
# ('SOLID', 1)
# ('DRY', 1)
# ('Secuity Software', 1)
# ('Веб-дизайн', 1)
# ('pega', 1)
# ('Анализ бизнес-процессов', 1)
# ('as is to be', 1)
# ('Asyncio', 1)
# ('Product', 1)
# ('Виртуальный ассистент', 1)
# ('B2C', 1)
# ('SAP', 1)
# ('ЭДО', 1)
# ('223 ФЗ', 1)
# ('Развитие ключевых клиентов', 1)
# ('Финансовый менеджмент', 1)
# ('Инновационный менеджмент', 1)
# ('152-ФЗ', 1)
# ('DATA PROTECTION', 1)
# ('Сопровождение клиентов', 1)
# ('Дизайн интерфейсов', 1)
# ('Usability', 1)
# ('Письменный перевод', 1)
# ('Электронный документооборот', 1)
# ('Бизнес-планирование', 1)
# ('Опыт работы в fintech компаниях', 1)
# ('Опыт работы в Контакт-центре', 1)
# ('Стандарты обслуживания клиентов', 1)
# ('Разработка регламентов', 1)
# ('План продвижения', 1)
# ('B2B Продажи', 1)
# ('интеграционные процессы', 1)
# ('SpringBoot', 1)
# ('Деловая этика', 1)
# ('ios sdk', 1)
# ('swift', 1)
# ('Реинжиниринг бизнес-процессов', 1)
# ('Прокладка кабелей', 1)
# ('IDEF', 1)
# ('Телефонные переговоры', 1)
# ('Маркетинговые исследования', 1)
# ('SAP MM', 1)
# ('SAP PM', 1)
# ('SAP LO', 1)
# ('SAP PS', 1)
# ('SAP R/3', 1)
# ('Helpdesk', 1)
# ('Методология бюджетирования', 1)
# ('Бухгалтерская отчетность', 1)
# ('1C: Бухгалтерия', 1)
# ('Корпоративное право', 1)
# ('стратегические партнерства', 1)
# ('M&A сделки', 1)
# ('openshift', 1)
# ('kafka', 1)
# ('Консультант плюс', 1)
# ('Согласование договоров', 1)
# ('Social Media Marketing', 1)
# ('Управление талантами', 1)
# ('ИТ-рекрутмент', 1)
# ('ИТ-подбор', 1)
# ('Навыки переговоров', 1)
# ('Управление процессами', 1)
# ('модернизация систем', 1)
# ('трейдинг', 1)
# ('розничное брокерское обслуживание.', 1)
# ('валютный рынок', 1)
# ('срочный рынок', 1)
# ('внеберживой рынок', 1)
# ('Риск-менеджмент', 1)
# ('трейдер', 1)
# ('Брокер', 1)
# ('телемеркетинг', 1)
# ('WEB аналитика', 1)
# ('HTTP', 1)
# ('Аналитика', 1)
# ('Yandex Metrics', 1)
# ('Исследование клиентского опыта', 1)
# ('REST API', 1)
# ('ASP.NET', 1)
# ('Ajax', 1)
# ('JDBC', 1)
# ('AppSec', 1)
# ('BugBounty', 1)
# ('SSDLC', 1)
# ('DAST', 1)
# ('NLP', 1)
# ('Deep Learning', 1)
# ('Коммуникативные навыки', 1)
# ('Цифровые навыки', 1)
# ('Навыки продаж', 1)
# ('Коммуникабельность', 1)
# ('Организация мероприятий', 1)
# ('Закупка товаров и услуг', 1)
# ('Оперативное планирование', 1)
# ('T-SQL', 1)
# ('Apache Superset', 1)
# ('Superset', 1)
# ('GreenPlum', 1)
# ('Clickhouse', 1)
# ('Составление отчетности', 1)
# ('Умение принимать решения', 1)
# ('Structuring', 1)
# ('Derivatives', 1)
# ('Banking', 1)
# ('Finance', 1)
# ('equity', 1)
# ('structured products', 1)
# ('bond', 1)
# ('structured finance', 1)
# ('quantitative analysis', 1)
# ('derivatives transactions', 1)
# ('security financing transactions', 1)
# ('Financial Analysis', 1)
# ('Business Analysis', 1)
# ('алгоритмическая торговля', 1)
# ('Финансовая отчетность', 1)
# ('Adobe InDesign', 1)
# ('Selenium IDE', 1)
# ('Helm', 1)
# ('Data Privacy', 1)
# ('GDPR', 1)
# ('Оценка рисков', 1)
# ('AppMetrica', 1)
# ('Firebase', 1)
# ('Crashlytics', 1)
# ('Защита персональных данных', 1)
# ('Wiki', 1)
# ('ASP.NET WebForms', 1)
# ('data science', 1)
# ('Developer Express', 1)
# ('DevExtreme', 1)
# ('HighCharts', 1)
# ('trading', 1)
# ('quantitative', 1)
# ('quant analyst', 1)
# ('алгоритмы', 1)
# ('ReactJS', 1)
# ('ES6', 1)
# ('Redux-saga', 1)
# ('Планирование маркетинговых кампаний', 1)
# ('Power BI', 1)
# ('Тайм-менеджмент', 1)
# ('разработка нормативных документов', 1)
# ('Agile', 1)
# ('Стратегическое мышление', 1)
# ('Управление знаниями', 1)
# ('Точность и внимательность к деталям', 1)
# ('Корпоративная этика', 1)
# ('Веб-программирование', 1)
# ('Лидерство', 1)
# ('Sketch', 1)
# ('Adobe Creative Cloud', 1)
# ('Principle', 1)
# ('Flinto', 1)
# ('Invision', 1)
# ('Планирование карьеры', 1)
# ('Управление персоналом', 1)
# ('Ответственность', 1)
# ('Unix Shell Scripts', 1)
# ('VCS', 1)
# ('Аналитика продаж', 1)
# ('Ценные бумаги', 1)
# ('Налоги', 1)
# ('Налоговый учет', 1)
# ('Депозитарные операции', 1)
# ('React.JS', 1)
# ('IDEF0', 1)
# ('EPC', 1)
# ('Web-service', 1)
# ('ESB', 1)
# ('JAVA,', 1)
# ('Perl', 1)
# ('WEB', 1)
# ('Разработка проектной документации', 1)
# ('Корректура текстов', 1)
# ('Навыки межличностного общения', 1)
# ('Ведение отчетности', 1)
# ('Обучение', 1)
# ('оформление документации', 1)
# ('cucumber', 1)
# ('Продажа страховых продуктов', 1)
# ('Электронная почта', 1)
# ('Ведение переписки', 1)
# ('AllFusion ERwin Data Modeler', 1)
# ('Работа с людьми', 1)
# ('Apache AirFlow', 1)
# ('Adobe After Effect', 1)
# ('Data Science', 1)
# ('Прогнозирование', 1)
# ('Управление продажами', 1)
# ('postman', 1)
# ('jmater', 1)
# ('IT', 1)
# ('Yii', 1)
# ('Информационная безопасность', 1)
# ('Product Owner', 1)
# ('Менеджер продукта', 1)
# ('RHEL', 1)
# ('Elastic', 1)
# ('Kaffka', 1)
# ('Flink', 1)
# ('Cassandra', 1)
# ('Прототипирование', 1)
# ('MDM', 1)
# ('Хранилище данных', 1)
# ('Data Lake', 1)
# ('Моделирование данных', 1)
# ('Витрина данных', 1)
# ('Entity Framework', 1)
# ('Windows 7', 1)
# ('Организационное развитие', 1)
# ('Написание научный статей', 1)
# ('R', 1)
# ('Анализ научных статей', 1)
# ('Market Research', 1)
# ('IPO', 1)
# ('Global Markets', 1)
# ('Equity Capital Markets', 1)
# ('Axure RP', 1)
# ('Google AdWords', 1)
# ('Контекстная реклама', 1)
# ('Интернет-реклама', 1)
# ('Google Analytics', 1)
# ('Яндекс.Метрика', 1)
# ('Моделирование процессов', 1)
# ('Mathcad', 1)
# ('Организация деловых поездок', 1)
# ('Делопроизводство', 1)
# ('Документооборот', 1)
# ('Административная поддержка руководителя', 1)
# ('Протоколирование', 1)
# ('эквайринг', 1)
# ('МСФО', 1)
# ('Rest API', 1)
# ('GRPC', 1)
# ('Groove', 1)
# ('Java 8 / 11; Spring Framework / Spring boot; JPA / Hibernate / JDBC; Docker / K8S / OpenShift; Micr', 1)
# ('Olap (online analytical processing)', 1)
